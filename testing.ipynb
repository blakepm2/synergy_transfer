# %%
from synergy_transfer.utils.get_data import hello
import pandas as pd

# %%
drug_DrugBank_target = pd.read_csv('data/drug_DrugBank_target.csv')
drug_lincs_target = pd.read_csv('data/drug_lincs_target.csv')
drug_TTD_target = pd.read_csv('data/drug_TTD_target.csv')
cell_line = pd.read_csv('data/cell_lines.csv')
cell_line_meta = pd.read_csv('data/cell_line_meta.csv')
cell_line_meta_modified = pd.read_csv('data/cell_line_meta_modified.csv')

# %%
drug_DrugBank_target.head()
# Out:
#     Gene uniprot_protein_acc_id drugbank_id  drug_name drug_action_type  \
# 0     F2                 P00734     DB00001  Lepirudin        Inhibitor
# 1   EGFR                 P00533     DB00002  Cetuximab       Antagonist
# 2   ERBB                 P00533     DB00002  Cetuximab       Antagonist
# 3  ERBB1                 P00533     DB00002  Cetuximab       Antagonist
# 4   HER1                 P00533     DB00002  Cetuximab       Antagonist
#
#   drug_status drug_status2
# 0     Biotech     Approved
# 1     Biotech     Approved
# 2     Biotech     Approved
# 3     Biotech     Approved
# 4     Biotech     Approved

# %%
drug_lincs_target.head()
# Out:
#    Unnamed: 0          dname    chembl_id                     inchikey  \
# 0         343  VALPROIC ACID    CHEMBL109  NIJJYAXOARWZEE-UHFFFAOYSA-N
# 1         321       PROBUCOL    CHEMBL608  FYPMFJGVHOHGLL-UHFFFAOYSA-N
# 2         476  CARBAMAZEPINE    CHEMBL108  FFGPTBGBLSHEPO-UHFFFAOYSA-N
# 3         440      PHENYTOIN     CHEMBL16  CXOFVDLJLONNDW-UHFFFAOYSA-N
# 4        3199    Tesmilifene  CHEMBL26424  NFIXBCVWIPOYCD-UHFFFAOYSA-N
#
#                                               smiles     cid  \
# 0                                    CCCC(CCC)C(=O)O    3121
# 1  CC(C)(C)C1=CC(=CC(=C1O)C(C)(C)C)SC(C)(C)SC2=CC...    4912
# 2               C1=CC=C2C(=C1)C=CC3=CC=CC=C3N2C(=O)N    2554
# 3          C1=CC=C(C=C1)C2(C(=O)NC(=O)N2)C3=CC=CC=C3    1775
# 4                CCN(CC)CCOC1=CC=C(C=C1)CC2=CC=CC=C2  108092
#
#   molecular_formula  clinical_phase         cid_m         cid_s  \
# 0           C8H16O2               4  CIDm00003121  CIDs00003121
# ...

# %%
drug_TTD_target.head()
# Out:
#         dname      chembl_id                     inchikey  \
# 0        5-FU      CHEMBL185  GHASVSINZRGABV-UHFFFAOYSA-N
# 1     AZD1775  CHEMBL1976040  BKWJAKQVGHWELA-UHFFFAOYSA-N
# 2     BEZ-235  CHEMBL1879463  JOGKUKXHTYWRGZ-UHFFFAOYSA-N
# 3  BORTEZOMIB   CHEMBL325041  GXJABQQUPOEUTA-RDJZCZTQSA-N
# 4   DASATINIB     CHEMBL1421  ZBNZXTGUTAYRHI-UHFFFAOYSA-N
#
#                                               smiles       cid  \
# 0                               C1=C(C(=O)NC(=O)N1)F      3385
# 1  CC(C)(C1=NC(=CC=C1)N2C3=NC(=NC=C3C(=O)N2CC=C)N...  24856436
# 2  CC(C)(C#N)C1=CC=C(C=C1)N2C3=C4C=C(C=CC4=NC=C3N...  11977753
# 3  B(C(CC(C)C)NC(=O)C(CC1=CC=CC=C1)NC(=O)C2=NC=CN...    387447
# 4  CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=NC(=NC(...   3062316
#
#   molecular_formula  clinical_phase         cid_m         cid_s  \
# 0         C4H3FN2O2               4  CIDm00003385  CIDs00003385
# 1        C27H32N8O2               2  CIDm24856436  CIDs24856436
# ...

# %%
cell_line_meta.head()
# Out:
#    id   name                                           synonyms  \
# 0   1  786-0  786-0; 786O; 786-0; 786.O; 786-O RCC; RCC 786-...
# 1   2  A2058                              A2058; A 2058; A-2058
# 2   3  A2780                        A2780; A-2780; 2780; A2780S
# 3   4   A375     A375; A 375; A375; A375-MEL; A375-mel; A375mel
# 4   5   A427                                         A427; A427
#
#   cellosaurus_accession  SANGAR_ID COSMIC_ID    BROAD_ID      CCLE_ID  tissue  \
# 0             CVCL_1051  SIDM00125    905947  ACH-000649  786O_KIDNEY  kidney
# 1             CVCL_1059  SIDM00797    906792  ACH-000788   A2058_SKIN    skin
# 2             CVCL_0134  SIDM00210    906804  ACH-000657  A2780_OVARY   ovary
# 3             CVCL_0132  SIDM00795    906793  ACH-000219    A375_SKIN    skin
# 4             CVCL_1055  SIDM00810    910851  ACH-000757    A427_LUNG    lung
#
#   disease_id
# 0      C9385
# 1      C3802
# 2      C7979
# 3      C3802
# 4      C3512

# %%
cell_line_meta_modified.head()
# Out:
#    id   name                                           synonyms  \
# 0   1  786-0  786-0; 786O; 786-0; 786.O; 786-O RCC; RCC 786-...
# 1   2  A2058                              A2058; A 2058; A-2058
# 2   3  A2780                        A2780; A-2780; 2780; A2780S
# 3   4   A375     A375; A 375; A375; A375-MEL; A375-mel; A375mel
# 4   5   A427                                         A427; A427
#
#   cellosaurus_accession  SANGAR_ID COSMIC_ID    BROAD_ID      CCLE_ID  tissue  \
# 0             CVCL_1051  SIDM00125    905947  ACH-000649  786O_KIDNEY  kidney
# 1             CVCL_1059  SIDM00797    906792  ACH-000788   A2058_SKIN    skin
# 2             CVCL_0134  SIDM00210    906804  ACH-000657  A2780_OVARY   ovary
# 3             CVCL_0132  SIDM00795    906793  ACH-000219    A375_SKIN    skin
# 4             CVCL_1055  SIDM00810    910851  ACH-000757    A427_LUNG    lung
#
#   disease_id
# 0      C9385
# 1      C3802
# 2      C7979
# 3      C3802
# 4      C3512

# %%
cell_line.head()
# Out:
#     name                                           synonyms  \
# 0  786-0  786-0; 786O; 786-0; 786.O; 786-O RCC; RCC 786-...
# 1  A2058                              A2058; A 2058; A-2058
# 2  A2780                        A2780; A-2780; 2780; A2780S
# 3   A375     A375; A 375; A375; A375-MEL; A375-mel; A375mel
# 4   A427                                         A427; A427
#
#   cellosaurus_accession disease_id  id  tissue_id   depmap_id  \
# 0             CVCL_1051      C9385   1        5.0  ACH-000649
# 1             CVCL_1059      C3802   2       10.0  ACH-000788
# 2             CVCL_0134      C7979   3        8.0  ACH-000657
# 3             CVCL_0132      C3802   4       10.0  ACH-000219
# 4             CVCL_1055      C3512   5        7.0  ACH-000757
#
#   cell_model_passport_id  cosmic_id    ccle_name expression_data
# 0              SIDM00125   905947.0  786O_KIDNEY    BROAD_DepMap
# 1              SIDM00797   906792.0   A2058_SKIN    BROAD_DepMap
# ...
